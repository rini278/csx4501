# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Pandas and plotting exercises

# %%
# Import the pandas library

import pandas as pd

# %% [markdown]
# In Week 2, you used a dataset from the CORGIS website.  You may have used either the Python, CSV, or JSON data files.
#
# For this assignment, use the CSV file format for the same category of data that you used previously.

# %%
# Use pandas read_csv function to import the data into a dataframe variable

df=pd.read_csv('real_estate.csv')

# %%
# How many rows and columns does the dataframe have?

df
# Out:
#      data.date data.owned or leased  data.parking spaces data.status  \
# 0     1933.1.1                OWNED                   29      ACTIVE
# 1     2019.1.1                OWNED                    0      ACTIVE
# 2     1933.1.1               LEASED                    2      ACTIVE
# 3     1963.1.1                OWNED                  103      ACTIVE
# 4     1967.1.1                OWNED                  131      ACTIVE
# ...        ...                  ...                  ...         ...
# 9124         0               LEASED                   24      ACTIVE
# 9125         0               LEASED                    7      ACTIVE
# 9126         0               LEASED                  221      ACTIVE
# 9127         0               LEASED                  288      ACTIVE
# 9128         0               LEASED                   40      ACTIVE
#
#      data.type location.congressional district location.id  \
# 0     BUILDING                               1      CT0013
# 1     BUILDING                               3      CT0024
# 2     BUILDING                               5      CT0047
# 3     BUILDING                               1      CT0053
# 4     BUILDING                               4      CT0059
# ...        ...                             ...         ...
# 9124  BUILDING                               3      NV8371
# 9125  BUILDING                               3      NV8403
# 9126  BUILDING                               2      NV8446
# 9127  BUILDING                               2      NV8447
# 9128  BUILDING                               1      NV8464
#
#       location.region id data.disabilities.ADA Accessible  \
# 0                      1                     Will Conform
# 1                      1                     Will Conform
# 2                      1                     Will Conform
# 3                      1                     Will Conform
# 4                      1                     Will Conform
# ...                  ...                              ...
# 9124                   9                     Will Conform
# 9125                   9                              Yes
# 9126                   9                              Yes
# 9127                   9                              Yes
# 9128                   9                     Will Conform
#
#       data.disabilities.ansi usable location.address.city  \
# 0                             97072              HARTFORD
# 1                             67717             NEW HAVEN
# 2                              7442             WATERBURY
# 3                            203175              HARTFORD
# 4                             86215            BRIDGEPORT
# ...                             ...                   ...
# 9124                          23669             LAS VEGAS
# 9125                          10894             LAS VEGAS
# 9126                          35839           CARSON CITY
# 9127                          34050            WINNEMUCCA
# 9128                           1787             LAS VEGAS
#
#      location.address.county  location.address.line 1 location.address.state  \
# 0            HARTFORD COUNTY              135 HIGH ST                     CT
# 1           NEW HAVEN COUNTY            141 CHURCH ST                     CT
# 2           NEW HAVEN COUNTY             135 GRAND ST                     CT
# 3            HARTFORD COUNTY              450 Main St                     CT
# 4           FAIRFIELD COUNTY       915 LAFAYETTE BLVD                     CT
# ...                      ...                      ...                    ...
# 9124            CLARK COUNTY       6750 VIA AUSTI PKY                     NV
# 9125            CLARK COUNTY        3595 E PATRICK LN                     NV
# 9126             CARSON CITY      5665 Morgan Mill Rd                     NV
# 9127         HUMBOLDT COUNTY   5100 E WINNEMUCCA BLVD                     NV
# 9128            CLARK COUNTY  3773 Howard Hughes Pkwy                     NV
#
#       location.address.zip
# 0                 61031125
# 1                 65102001
# 2                 67029998
# 3                 61031804
# 4                 66044706
# ...                    ...
# 9124             891193565
# 9125             891203214
# 9126             897011448
# 9127             894452921
# 9128             891690922
#
# [9129 rows x 15 columns]

# %%
# What are the column names of the dataframe?

col=df.columns
print(col)
# Out:
# Index(['data.date', 'data.owned or leased', 'data.parking spaces',
#        'data.status', 'data.type', 'location.congressional district',
#        'location.id', 'location.region id', 'data.disabilities.ADA Accessible',
#        'data.disabilities.ansi usable', 'location.address.city',
#        'location.address.county', 'location.address.line 1',
#        'location.address.state', 'location.address.zip'],
#       dtype='object')

# %%
# What are the datatypes of each column?

dtype=pd.DataFrame(df)
print(dtype.dtypes)
# Out:
# data.date                           object
# data.owned or leased                object
# data.parking spaces                  int64
# data.status                         object
# data.type                           object
# location.congressional district     object
# location.id                         object
# location.region id                   int64
# data.disabilities.ADA Accessible    object
# data.disabilities.ansi usable        int64
# location.address.city               object
# location.address.county             object
# location.address.line 1             object
# location.address.state              object
# location.address.zip                 int64
# dtype: object

# %%
# Look at the first 2 rows of the dataframe

df.head(2)
# Out:
#   data.date data.owned or leased  data.parking spaces data.status data.type  \
# 0  1933.1.1                OWNED                   29      ACTIVE  BUILDING
# 1  2019.1.1                OWNED                    0      ACTIVE  BUILDING
#
#   location.congressional district location.id  location.region id  \
# 0                               1      CT0013                   1
# 1                               3      CT0024                   1
#
#   data.disabilities.ADA Accessible  data.disabilities.ansi usable  \
# 0                     Will Conform                          97072
# 1                     Will Conform                          67717
#
#   location.address.city location.address.county location.address.line 1  \
# 0              HARTFORD         HARTFORD COUNTY             135 HIGH ST
# 1             NEW HAVEN        NEW HAVEN COUNTY           141 CHURCH ST
#
#   location.address.state  location.address.zip
# 0                     CT              61031125
# 1                     CT              65102001

# %%
# Look at the last 2 rows of the dataframe

df.tail(2)
# Out:
#      data.date data.owned or leased  data.parking spaces data.status  \
# 9127         0               LEASED                  288      ACTIVE
# 9128         0               LEASED                   40      ACTIVE
#
#      data.type location.congressional district location.id  \
# 9127  BUILDING                               2      NV8447
# 9128  BUILDING                               1      NV8464
#
#       location.region id data.disabilities.ADA Accessible  \
# 9127                   9                              Yes
# 9128                   9                     Will Conform
#
#       data.disabilities.ansi usable location.address.city  \
# 9127                          34050            WINNEMUCCA
# 9128                           1787             LAS VEGAS
#
#      location.address.county  location.address.line 1 location.address.state  \
# 9127         HUMBOLDT COUNTY   5100 E WINNEMUCCA BLVD                     NV
# 9128            CLARK COUNTY  3773 Howard Hughes Pkwy                     NV
#
#       location.address.zip
# 9127             894452921
# 9128             891690922

# %%
# Print out summary statistics about the dataframe
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9129 entries, 0 to 9128
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   data.date                         9129 non-null   object
#  1   data.owned or leased              9129 non-null   object
#  2   data.parking spaces               9129 non-null   int64
#  3   data.status                       9129 non-null   object
#  4   data.type                         9129 non-null   object
#  5   location.congressional district   9129 non-null   object
#  6   location.id                       9129 non-null   object
#  7   location.region id                9129 non-null   int64
#  8   data.disabilities.ADA Accessible  9129 non-null   object
#  9   data.disabilities.ansi usable     9129 non-null   int64
#  10  location.address.city             9129 non-null   object
#  11  location.address.county           9129 non-null   object
#  12  location.address.line 1           9129 non-null   object
#  13  location.address.state            9129 non-null   object
#  14  location.address.zip              9129 non-null   int64
# dtypes: int64(4), object(11)
# memory usage: 1.0+ MB
#        data.parking spaces  location.region id  data.disabilities.ansi usable  \
# count          9129.000000         9129.000000                   9.129000e+03
# mean             50.947092            6.222916                   3.335182e+04
# std             189.305939            2.896577                   9.477075e+04
# min               0.000000            1.000000                   0.000000e+00
# 25%               0.000000            4.000000                   2.535000e+03
# 50%               8.000000            7.000000                   7.629000e+03
# 75%              39.000000            9.000000                   2.135300e+04
# max            6600.000000           11.000000                   1.989117e+06
#
#        location.address.zip
# count          9.129000e+03
# mean           4.668926e+08
# std            3.243496e+08
# min            6.050000e+02
# 25%            2.002421e+08
# 50%            4.321511e+08
# 75%            7.852168e+08
# max            9.990200e+08

# %%
# Choose a column and print out the column (it's ok if the output is abbreviated)

df['data.date']
# Out:
# 0       1933.1.1
# 1       2019.1.1
# 2       1933.1.1
# 3       1963.1.1
# 4       1967.1.1
#           ...
# 9124           0
# 9125           0
# 9126           0
# 9127           0
# 9128           0
# Name: data.date, Length: 9129, dtype: object

# %%
# Choose a column that has numeric values and make a line plot of the values

# a=df.loc[df['data.parking spaces']]
# a.plot(kind='line',y='data.parking spaces')
df.groupby('data.owned or leased').plot(kind='line',y='data.parking spaces')
# Out:
# data.owned or leased
# LEASED    AxesSubplot(0.125,0.125;0.775x0.755)
# OWNED     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# Use "loc" to print out the first 10 elements of the plotted column

df.loc[0:10,'data.parking spaces']
# Out:
# 0      29
# 1       0
# 2       2
# 3     103
# 4     131
# 5       5
# 6      74
# 7     164
# 8       8
# 9       1
# 10      0
# Name: data.parking spaces, dtype: int64

# %%
# Use "loc" to print out the first 10 elements of the plotted column
# as well as the matching 10 elements of a different column that has interesting text

df.loc[0:10,['data.parking spaces','location.address.city']]
# Out:
#     data.parking spaces location.address.city
# 0                    29              HARTFORD
# 1                     0             NEW HAVEN
# 2                     2             WATERBURY
# 3                   103              HARTFORD
# 4                   131            BRIDGEPORT
# 5                     5            TORRINGTON
# 6                    74             NEW HAVEN
# 7                   164         EAST HARTFORD
# 8                     8              STAMFORD
# 9                     1            MIDDLETOWN
# 10                    0         EAST HARTFORD

# %%
# Assign the dataframe values from the previous cell into a new dataframe variable
# and make a bar plot with the text values horizontally and the numeric values as the bar heights

res=pd.DataFrame()
res=df.loc[0:10,['data.parking spaces','location.address.city']]
res.plot(kind='bar',x='location.address.city',y='data.parking spaces')
# Out:
# <AxesSubplot:xlabel='location.address.city'>

# %%
# Re-do the plot from the previous cell as a horizontal bar plot

res.plot(kind='barh',x='location.address.city',y='data.parking spaces')
# Out:
# <AxesSubplot:ylabel='location.address.city'>

# %%
# Re-do the plot from the previous cell
# and change at least two aesthetic elements (colors, labels, titles, ...)

res.plot(kind='barh',x='location.address.city',y='data.parking spaces',color='r', ylabel='Number of parking spaces in the city',xlabel='City')
# Out:
# <AxesSubplot:ylabel='City'>

# %% [markdown]
# # Free form section

# %% [markdown]
# * Choose another type of plot that interests you from the [pandas.DataFrame.plot documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#) [look at the 'kind' parameter] and make a new plot of your dataset values using the plot type

# %%
res.plot(kind='scatter',y='location.address.city',x='data.parking spaces',ylabel='City',xlabel='Number of parking spaces')
# Out:
# <AxesSubplot:xlabel='Number of parking spaces', ylabel='City'>

# %% [markdown]
# * Copy some of your analysis from the Week 2 assignment into new cells below
# * Clean them up if desired, and make sure that you translate them to work with your new pandas dataframe structure here if needed
# * Create several plots to complement and extend your analysis

# %%
p1=pd.DataFrame()
p1=df.loc[0:100,['data.parking spaces','data.disabilities.ansi usable']]
p1.plot(kind='hist',x='data.parking spaces',y='data.disabilities.ansi usable')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
p2=pd.DataFrame()
p2=df.loc[200:220,['data.status','data.disabilities.ansi usable']]
p2.plot(kind='pie',x='data.status',y='data.disabilities.ansi usable')
# Out:
# <AxesSubplot:ylabel='data.disabilities.ansi usable'>

# %%
import real_estate
import pickle as _pickle

building = real_estate.get_building()

current = 0
countpark = 0
while current < 100:
    if(building[current]['location']['congressional district'] == '3' ):
        countpark += building[current]['data']['parking spaces']
    current += 1
print("Total number of parking spaces in 3rd congressional district is : ",countpark)

p3=df.loc[0:100,['data.parking spaces','location.congressional district']]
#p3.plot(kind='line',y='data.parking spaces',x='location.congressional district')
p3.groupby('location.congressional district').plot(kind='line',y='data.parking spaces',x='location.congressional district')
# Out:
# Total number of parking spaces in 3rd congressional district is :  3266
# location.congressional district
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 3    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# 5    AxesSubplot(0.125,0.125;0.775x0.755)
# 6    AxesSubplot(0.125,0.125;0.775x0.755)
# 7    AxesSubplot(0.125,0.125;0.775x0.755)
# 8    AxesSubplot(0.125,0.125;0.775x0.755)
# 9    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
